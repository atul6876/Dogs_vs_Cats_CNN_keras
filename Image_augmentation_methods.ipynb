# %%
# Import the neccesary modules:

import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Function to artificially augment your dataset. Especially helpful when 

from keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

datagen = ImageDataGenerator(rotation_range=40, # range of rotation angle (could be 0-180 degrees)
    width_shift_range=0.2,                      # portion of the image to shift horizontally
    height_shift_range=0.2,                     # portion of the image to shift vertically
    brightness_range=None,                      # Range of altering brightness levels, no
    shear_range=0.2,                            # range of shearing transformation
    zoom_range=0.2,                             # range of zooming into the image
    horizontal_flip=True,                       # randomly flipping images horizontally
    fill_mode='nearest')                        # filling methodology for missing pixels after aforementioned transformations

img=load_img('train/cats/cat.2.jpg')

x=img_to_array(img)
x=x.reshape((1,)+x.shape)

i=0

for batch in datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='cat', save_format='jpeg'):
    i+=1
    if i>=10: # limiting the number of transfromed images to 10
        break

# %%
from os import listdir
from PIL import Image as PImage

def loadImages(path):
    """ return an array of images. Also, displays each image in the notebook"""

    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        display(img)
        loadedImages.append(img)

    return loadedImages

# %%
# Visualizing the generated images after randomly introducing aforementioned tranformations

path = "preview/"
imgs = loadImages(path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1582CC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1582CF8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1621DD8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1621E48>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFC93E5978>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFC93E5710>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1535080>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1235048>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD15825F8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x396 at 0x1DFD1582588>
